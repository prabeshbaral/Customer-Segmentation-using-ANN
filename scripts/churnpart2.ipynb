# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
import pandas as pd

# %%
df=pd.read_csv('../datasets/telecom.csv')
df.shape
# Out:
# (7032, 36)

# %%
X=df.drop(['Unnamed: 0','Churn'],axis=1)
y=df['Churn']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y , test_size=0.3)

# %%
model = keras.Sequential(
[
    keras.layers.Dense(30,input_shape=(34,), activation='relu'),
    keras.layers.Dense(1,activation='sigmoid')
]
)

# %%
model.compile(
    loss= 'binary_crossentropy',
    metrics= ['accuracy'],
    optimizer='adam'

)
model.fit(X_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - accuracy: 0.7167 - loss: 55.1234
# Epoch 2/10
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 494us/step - accuracy: 0.7452 - loss: 0.6783
# Epoch 3/10
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - accuracy: 0.7355 - loss: 0.6427
# Epoch 4/10
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step - accuracy: 0.7548 - loss: 0.6522
# Epoch 5/10
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step - accuracy: 0.7560 - loss: 0.5937
# Epoch 6/10
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - accuracy: 0.7562 - loss: 0.6606
# Epoch 7/10
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - accuracy: 0.7761 - loss: 0.5136
# Epoch 8/10
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step - accuracy: 0.7627 - loss: 0.8451
# Epoch 9/10
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - accuracy: 0.7703 - loss: 0.5998
# Epoch 10/10
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step - accuracy: 0.7761 - loss: 0.5364

# %%
model.evaluate(X_test,y_test)
# Out:
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step - accuracy: 0.6575 - loss: 0.6927
# [0.7127708196640015, 0.6421800851821899]

# %%
y_pred=model.predict(X_test)
# Out:
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step

# %%
y_pred[:5]
# Out:
# array([[0.18991978],
#        [0.6817002 ],
#        [0.60910857],
#        [0.8941687 ],
#        [0.9289978 ]], dtype=float32)

# %%
y_prediction=[]
for element in y_pred:
    if element<0.6:
        y_prediction.append(0)
    else:
        y_prediction.append(1)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,y_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.62      0.74      1528
#            1       0.45      0.80      0.58       582
#
#     accuracy                           0.67      2110
#    macro avg       0.67      0.71      0.66      2110
# weighted avg       0.77      0.67      0.69      2110

# %%
cm=confusion_matrix(y_test,y_prediction)
cm
# Out:
# array([[955, 573],
#        [114, 468]])

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
import pandas as pd

# %%
df=pd.read_csv('../datasets/telecom.csv')
df.shape
# Out:
# (7032, 36)

# %%
X=df.drop(['Unnamed: 0','Churn'],axis=1)
y=df['Churn']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y , test_size=0.3)

# %%
model = keras.Sequential(
[
    keras.layers.Dense(30,input_shape=(34,), activation='relu'),
    keras.layers.Dense(1,activation='sigmoid')
]
)
# Out:
# /Users/pradipbaral/Desktop/customer_segmentation_using_ann/customerseg/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    loss= 'binary_crossentropy',
    metrics= ['accuracy'],
    optimizer='adam'

)
model.fit(X_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step - accuracy: 0.7134 - loss: 2.8072
# Epoch 2/10
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - accuracy: 0.7678 - loss: 0.5478
# Epoch 3/10
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 455us/step - accuracy: 0.7528 - loss: 0.6277
# Epoch 4/10
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 460us/step - accuracy: 0.7632 - loss: 0.6183
# Epoch 5/10
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 460us/step - accuracy: 0.7617 - loss: 0.5428
# Epoch 6/10
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 448us/step - accuracy: 0.7748 - loss: 0.6301
# Epoch 7/10
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step - accuracy: 0.7853 - loss: 0.5257
# Epoch 8/10
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - accuracy: 0.7572 - loss: 0.6854
# Epoch 9/10
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - accuracy: 0.7721 - loss: 0.6126
# Epoch 10/10
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step - accuracy: 0.7723 - loss: 0.5918

# %%
model.evaluate(X_test,y_test)
# Out:
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step - accuracy: 0.7831 - loss: 1.0964
# [1.1012253761291504, 0.7848341464996338]

# %%
y_pred=model.predict(X_test)
# Out:
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step

# %%
y_pred[:5]
# Out:
# array([[6.0660083e-02],
#        [1.3787302e-02],
#        [2.9143440e-08],
#        [6.6926359e-04],
#        [2.8147795e-10]], dtype=float32)

# %%
y_prediction=[]
for element in y_pred:
    if element<0.6:
        y_prediction.append(0)
    else:
        y_prediction.append(1)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,y_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.98      0.87      1550
#            1       0.82      0.20      0.32       560
#
#     accuracy                           0.78      2110
#    macro avg       0.80      0.59      0.59      2110
# weighted avg       0.79      0.78      0.72      2110

# %%
cm=confusion_matrix(y_test,y_prediction)
cm
# Out:
# array([[1525,   25],
#        [ 447,  113]])

# %% [markdown]
# ## the dataset is imblance so we are balancing the datasets

# %% [markdown]
# # Smoteenn for synthetic data

# %%
from imblearn.combine import SMOTEENN

# %%
y.value_counts()
# Out:
# Churn
# 0    5163
# 1    1869
# Name: count, dtype: int64

# %%
smote_enn = SMOTEENN(random_state=42)

# %%
X_resampled, y_resampled = smote_enn.fit_resample(X,y)

# %%
y_resampled.value_counts()
# Out:
# Churn
# 1    3173
# 0    2664
# Name: count, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled , test_size=0.2 , random_state=42)

# %%
model = keras.Sequential(
[
    keras.layers.Dense(30,input_shape=(34,), activation='relu'),
    keras.layers.Dense(1,activation='sigmoid')
]
)
model.compile(
    loss= 'binary_crossentropy',
    metrics= ['accuracy'],
    optimizer='adam'

)
model.fit(X_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# /Users/pradipbaral/Desktop/customer_segmentation_using_ann/customerseg/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - accuracy: 0.4972 - loss: 10.1191
# Epoch 2/10
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step - accuracy: 0.8583 - loss: 0.4046
# Epoch 3/10
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - accuracy: 0.8817 - loss: 0.3038
# Epoch 4/10
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - accuracy: 0.8435 - loss: 0.8334
# Epoch 5/10
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - accuracy: 0.8997 - loss: 0.3046
# Epoch 6/10
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step - accuracy: 0.9076 - loss: 0.3031
# Epoch 7/10
# ...

# %%
y_pred=model.predict(X_test)
y_prediction=[]
for element in y_pred:
    if element<0.6:
        y_prediction.append(0)
    else:
        y_prediction.append(1)
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step

# %%
print(classification_report(y_test,y_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.96      0.88       570
#            1       0.95      0.80      0.87       598
#
#     accuracy                           0.88      1168
#    macro avg       0.89      0.88      0.88      1168
# weighted avg       0.89      0.88      0.88      1168

# %% [markdown]
# ## now the accuracy has been increased we can use this model to guess or predict the result.

# %% [markdown]
# ### now we will use pickel to save the model

# %%
import pickle

# %%
filename = 'model.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
model_columns = X_train.columns  # Replace X_train with your training DataFrame
with open('model_columns.pkl', 'wb') as f:
    pickle.dump(model_columns, f)
